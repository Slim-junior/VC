# %% [markdown]
# <a href="https://colab.research.google.com/github/Slim-junior/VC/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('TESLA Search Trend vs Price.csv')
df =pd.read_csv('Bitcoin Search Trend.csv')
df =pd.read_csv('Daily Bitcoin Price.csv')
Un_employ =pd.read_csv('UE Benefits Search vs UE Rate 2004-20.csv')

# %%
tesla = pd.read_csv('TESLA Search Trend vs Price.csv')

# %%
tesla.columns
# Out:
# Index(['MONTH', 'TSLA_WEB_SEARCH', 'TSLA_USD_CLOSE'], dtype='object')

# %%
tesla.isna()
# Out:
#      MONTH  TSLA_WEB_SEARCH  TSLA_USD_CLOSE
# 0    False            False           False
# 1    False            False           False
# 2    False            False           False
# 3    False            False           False
# 4    False            False           False
# ..     ...              ...             ...
# 119  False            False           False
# 120  False            False           False
# 121  False            False           False
# 122  False            False           False
# 123  False            False           False
#
# [124 rows x 3 columns]

# %%
tesla['TSLA_WEB_SEARCH']
# Out:
# 0       3
# 1       3
# 2       2
# 3       2
# 4       2
#        ..
# 119    16
# 120    17
# 121    24
# 122    23
# 123    31
# Name: TSLA_WEB_SEARCH, Length: 124, dtype: int64

# %%
tesla['TSLA_WEB_SEARCH'].describe()
# Out:
# count    124.000000
# mean       8.725806
# std        5.870332
# min        2.000000
# 25%        3.750000
# 50%        8.000000
# 75%       12.000000
# max       31.000000
# Name: TSLA_WEB_SEARCH, dtype: float64

# %%
print(f'Smallest value in TSLA_WEB_SEARCH: {tesla.TSLA_WEB_SEARCH}.min()')
print(f'Largest value in TSLA_USD_CLOSE: {tesla.TSLA_USD_CLOSE}.max()')
# Out:
# Smallest value in TSLA_WEB_SEARCH: 0       3
# 1       3
# 2       2
# 3       2
# 4       2
#        ..
# 119    16
# 120    17
# 121    24
# 122    23
# 123    31
# Name: TSLA_WEB_SEARCH, Length: 124, dtype: int64.min()
# Largest value in TSLA_USD_CLOSE: 0        4.766000
# 1        3.988000
# 2        3.896000
# 3        4.082000
# 4        4.368000
#           ...
# 119    167.000000
# 120    215.962006
# 121    286.152008
# 122    498.320007
# 123    407.339996
# Name: TSLA_USD_CLOSE, Length: 124, dtype: float64.max()

# %%
print(f"Maximum 'TSLA_WEB_SEARCH' value using .max(): {tesla['TSLA_WEB_SEARCH'].max()}")
print(f"Maximum 'TSLA_USD_CLOSE' value using .max(): {tesla['TSLA_USD_CLOSE'].max()}")
# Out:
# Maximum 'TSLA_WEB_SEARCH' value using .max(): 31
# Maximum 'TSLA_USD_CLOSE' value using .max(): 498.320007

# %%
tesla.describe()
# Out:
#        TSLA_WEB_SEARCH  TSLA_USD_CLOSE
# count       124.000000      124.000000
# mean          8.725806       50.962145
# std           5.870332       65.908389
# min           2.000000        3.896000
# 25%           3.750000        7.352500
# 50%           8.000000       44.653000
# 75%          12.000000       58.991999
# max          31.000000      498.320007

# %%
btc_search =pd.read_csv('Daily Bitcoin Price.csv')

# %%
btc_search.shape
btc_search.head()
# Out:
#          DATE       CLOSE      VOLUME
# 0  2014-09-17  457.334015  21056800.0
# 1  2014-09-18  424.440002  34483200.0
# 2  2014-09-19  394.795990  37919700.0
# 3  2014-09-20  408.903992  36863600.0
# 4  2014-09-21  398.821014  26580100.0

# %%
daily_bt_price =pd.read_csv('Daily Bitcoin Price.csv')

# %%
daily_bt_price.isna()
# Out:
#        DATE  CLOSE  VOLUME
# 0     False  False   False
# 1     False  False   False
# 2     False  False   False
# 3     False  False   False
# 4     False  False   False
# ...     ...    ...     ...
# 2199  False  False   False
# 2200  False  False   False
# 2201  False  False   False
# 2202  False  False   False
# 2203  False  False   False
#
# [2204 rows x 3 columns]

# %%
tesla.isna()
# Out:
#      MONTH  TSLA_WEB_SEARCH  TSLA_USD_CLOSE
# 0    False            False           False
# 1    False            False           False
# 2    False            False           False
# 3    False            False           False
# 4    False            False           False
# ..     ...              ...             ...
# 119  False            False           False
# 120  False            False           False
# 121  False            False           False
# 122  False            False           False
# 123  False            False           False
#
# [124 rows x 3 columns]

# %%
btc_search.isna()
# Out:
#        DATE  CLOSE  VOLUME
# 0     False  False   False
# 1     False  False   False
# 2     False  False   False
# 3     False  False   False
# 4     False  False   False
# ...     ...    ...     ...
# 2199  False  False   False
# 2200  False  False   False
# 2201  False  False   False
# 2202  False  False   False
# 2203  False  False   False
#
# [2204 rows x 3 columns]

# %%
print(f'Missing values for Tesla?: {tesla.isna().values.any()}')
print(f'Missing values for U/E?: {Un_employ.isna().values.any()}')
print(f'Missing values for BTC Search?: {btc_search.isna().values.any()}')
# Out:
# Missing values for Tesla?: False
# Missing values for U/E?: False
# Missing values for BTC Search?: True

# %%
print(f'Missing values for BTC Search?: {btc_search.isna().values.sum()}')
print(f'Missing values for BTC Search?: {btc_search.CLOSE.isna()}')
# Out:
# Missing values for BTC Search?: 2
# Missing values for BTC Search?: 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2199    False
# 2200    False
# 2201    False
# 2202    False
# 2203    False
# Name: CLOSE, Length: 2204, dtype: bool

# %%
btc_search['DATE'] = pd.to_datetime(btc_search['DATE'])
btc_search.head()
# Out:
#         DATE       CLOSE      VOLUME
# 0 2014-09-17  457.334015  21056800.0
# 1 2014-09-18  424.440002  34483200.0
# 2 2014-09-19  394.795990  37919700.0
# 3 2014-09-20  408.903992  36863600.0
# 4 2014-09-21  398.821014  26580100.0

# %%
btc_search['DATE'] = pd.to_datetime(btc_search['DATE'])

print('Converted date column in btc_search.')
# Out:
# Converted date column in btc_search.

# %%
daily_bt_price['DATE'] = pd.to_datetime(daily_bt_price['DATE'])
df['DATE'] = pd.to_datetime(df['DATE'])
Un_employ['MONTH'] = pd.to_datetime(Un_employ['MONTH'])
tesla['MONTH'] = pd.to_datetime(tesla['MONTH'])

print('Converted date columns in daily_bt_price, df, Un_employ, and tesla.')
# Out:
# Converted date columns in daily_bt_price, df, Un_employ, and tesla.

# %%
tesla.MONTH.head()
# Out:
# 0   2010-06-01
# 1   2010-07-01
# 2   2010-08-01
# 3   2010-09-01
# 4   2010-10-01
# Name: MONTH, dtype: datetime64[ns]

# %%
btc_search = daily_bt_price.resample('ME', on='DATE').last()
btc_search.head()
# Out:
#                  CLOSE      VOLUME
# DATE
# 2014-09-30  386.944000  34707300.0
# 2014-10-31  338.321014  12545400.0
# 2014-11-30  378.046997   9194440.0
# 2014-12-31  320.192993  13942900.0
# 2015-01-31  217.464005  23348200.0

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

ax1 = plt.gca()
ax2 = ax1.twinx()
ax1.set_ylabel('TSLA Stock Price', color='#E6232E') # can use a HEX code
ax2.set_ylabel('Search Trend', color='skyblue')
ax1.plot(tesla.MONTH, tesla.TSLA_USD_CLOSE, color='#E6232E')
ax2.plot(tesla.MONTH, tesla.TSLA_WEB_SEARCH, color='skyblue')

# %%
plt.figure(figsize=(14,8), dpi=120)
plt.title('Tesla Web Search vs Price', fontsize=18)

ax1 = plt.gca()
ax2 = ax1.twinx()

# Also, increase fontsize and linewidth for larger charts
ax1.set_ylabel('TSLA Stock Price', color='#D6D331', fontsize=14)
ax2.set_ylabel('Search Trend', color='skyblue', fontsize=14)

ax1.plot(tesla.MONTH, tesla.TSLA_USD_CLOSE, color='#D6D331')
ax2.plot(tesla.MONTH, tesla.TSLA_WEB_SEARCH, color='skyblue')

# %% [markdown]
# plt.figure(figsize=(14,8), dpi=120)
# plt.title('Tesla Web Search vs Price', fontsize=18)
#
# # Increase the size and rotate the labels on the x-axis
# plt.xticks(fontsize=14, rotation=45)
#
# ax1 = plt.gca()
# ax2 = ax1.twinx()
# ax1.set_ylabel('TSLA Stock Price', color='#E6232E', fontsize=14)
# ax2.set_ylabel('Search Trend', color='skyblue', fontsize=14)
#
# ax1.set_ylim([0, 600])
# ax1.set_xlim([tesla.min(), df_tesla.MONTH.max()])

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

plt.figure(figsize=(14,8), dpi=120)
plt.title('Tesla Web Search vs Price', fontsize=18)

ax1 = plt.gca()
ax2 = ax1.twinx()

ax1.set_ylabel('TSLA Stock Price', color='#E6232E', fontsize=14)
ax2.set_ylabel('Search Trend', color='skyblue', fontsize=14)

# Set the minimum and maximum values on the axes
ax1.set_ylim([0, 600])
ax1.set_xlim([tesla.MONTH.min(), tesla.MONTH.max()])

years = mdates.YearLocator()
months = mdates.MonthLocator()
years_fmt = mdates.DateFormatter('%Y')

# Add x-axis tick formatting
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)

ax1.plot(tesla.MONTH, tesla.TSLA_USD_CLOSE, color='#E6232E', linewidth=3)
ax2.plot(tesla.MONTH, tesla.TSLA_WEB_SEARCH, color='skyblue', linewidth=3)

plt.show()

# %%
years =mdates.YearLocator()
months = mdates.MonthLocator()
years_fmt = mdates.DateFormatter('%Y')

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd # Ensure pandas is imported for read_csv

plt.figure(figsize=(14,8), dpi=120)

plt.title('Bitcoin News Search vs Resampled Price', fontsize=18)
plt.xticks(fontsize=14, rotation=45)

ax1 = plt.gca()
ax2 = ax1.twinx()

ax1.set_ylabel('BTC Price', color='#F08F2E', fontsize=14)
ax2.set_ylabel('Search Trend', color='skyblue', fontsize=14)

# Assuming years, months, years_fmt are defined globally or imported, as seen in previous cells
# If not, they would need to be defined here:
# years = mdates.YearLocator()
# months = mdates.MonthLocator()
# years_fmt = mdates.DateFormatter('%Y')

ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)

ax1.set_ylim(bottom=0, top=15000)
ax1.set_xlim([btc_search.index.min(), btc_search.index.max()]) # Use btc_search index for x-limits

# Load the Bitcoin Search Trend data here
bitcoin_search_trends_df = pd.read_csv('Bitcoin Search Trend.csv')
bitcoin_search_trends_df['MONTH'] = pd.to_datetime(bitcoin_search_trends_df['MONTH']) # Convert date column
bitcoin_search_trends_df.set_index('MONTH', inplace=True) # Set 'MONTH' as index

# Experiment with the linestyle and markers
ax1.plot(btc_search.index, btc_search.CLOSE, # Use btc_search.index here
         color='#F08F2E', linewidth=3, linestyle='--')
ax2.plot(bitcoin_search_trends_df.index, bitcoin_search_trends_df.BTC_NEWS_SEARCH, # Use the new DataFrame for search trends
         color='skyblue', linewidth=3, marker='o')

plt.show() # Add plt.show() to display the plot
